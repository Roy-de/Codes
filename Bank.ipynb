# %%
import random

# %%
#define and initialize the parameters of the Poisson distributions
lambd_in = 0.5
lambd_out = 0.4
#bank variables
closing_time =  100      #initialize the bank closing time 
overtime = 0             #overtime the employees need to be paid for

# %%
#queue variables
num_arrivals = 0    #number of people in the que
num_departures = 0  #number of people who have been served
n = 0               #length of the queue  
max_line_length = 0 #the maximum length of the waiting line:

# %%
#time variables
t = 0                                       #set the time of first arrival to 0
time_depart = float('inf')                  #set the first time of departure to infinity
time_arrive = random.expovariate(lambd_in)  #generate the first arrival

departures = []
arrivals = []

while t < closing_time or n >= 0:
        
    # case 1 - within business hours, a customer arrives before any customer leaves the queue 
    if time_arrive <= time_depart and time_arrive <= closing_time:
        
        t = time_arrive      # move time along to the time of the new arrival
        num_arrivals += 1    # increase the number of customers with the additional arrival
        n += 1   
    # generate time of next arrival
    time_arrive = random.expovariate(lambd_in) + t

    #append the new customer to the arrival list
    arrivals.append(t)
    print("Arrival ", num_arrivals, "at time ", t)


    # generate time of departure 
    if n == 1:
        Y = random.expovariate(lambd_out)
        time_depart = t + Y
        
        '''
        print('Arrivals', arrivals)
        print('Departures', departures)'''
            
    # case 2 - within business hours, a customer departs before the next arrival
    elif time_depart < time_arrive and time_depart <= closing_time:
        
        # advance time to the next departure time
        t = time_depart
        
        # one more person served -> increase the count of clients who have been served
        num_departures += 1
        
        #update the departure list
        departures.append(t)
        print("Departure ", num_departures, "at time ", t)
        
        # one less person in line -> decrease the size of the waiting line
        n -= 1
        
        # if the queue is empt -> set the time of the next departure to infinity
        if n == 0:
            time_depart = float('inf')
            
        # if the queue isn't empty, generate the next time of departure
        else:
            Y = random.expovariate(lambd_out)
            time_depart = t + Y
        
        '''
        print('Arrivals', arrivals)
        print('Departures', departures)'''    
                
        # case 3 - next arrival/departure happens after closing time and there are people still in the queue
    elif min(time_arrive, time_depart) > closing_time and n > 0:
        
        # advance time to next departure
        t = time_depart
        
        #update the departure list
        departures.append(t)
        
        #update the number of departures/clients served
        num_departures += 1     # one more person served
        
        print("Departure ", num_departures, "at time ", t)
        
        #update the queue
        n -= 1    # one less person in the waiting line
        
        
        # if line isn't empty, generate the time of the next departure
        if n > 0:
            Y = random.expovariate(lambd_out)
            time_depart = t + Y
        
        '''
        print('Arrivals', arrivals)
        print('Departures', departures) '''
        
        
        
    # case 4 - next arrival/departure happens after closing time and there is nobody left in the queue
    elif min(time_arrive, time_depart) > closing_time and n == 0:
        
        # calculate overtime
        overtime = max(t - closing_time, 0)
        print('Overtime = ', overtime)
        
        '''
        print('Arrivals', arrivals)
        print('Departures', departures)'''
# Out:
# Arrival  115 at time  0.6812569158847501
# Arrival  116 at time  1.467494559334374
# Arrival  117 at time  4.797636708059848
# Arrival  118 at time  4.8837988806419075
# Arrival  119 at time  5.060777751625845
# Arrival  120 at time  5.142471141794978
# Arrival  121 at time  6.1218665218263375
# Arrival  122 at time  6.900171907182944
# Arrival  123 at time  9.839994822726647
# Arrival  124 at time  9.967833273857638
# Arrival  125 at time  11.238342553330062
# Arrival  126 at time  12.283388381781823
# Arrival  127 at time  13.313827500756716
# Arrival  128 at time  14.830702629275688
# Arrival  129 at time  18.512244420453968
# Arrival  130 at time  19.727808134700048
# Arrival  131 at time  20.700321398200963
# Arrival  132 at time  25.63694521234318
# Arrival  133 at time  27.052986024551036
# Arrival  134 at time  29.029696848246008
# Arrival  135 at time  29.156154170728243
# Arrival  136 at time  30.347147947564014
# Arrival  137 at time  30.734555513970786
# Arrival  138 at time  33.27664841092509
# Arrival  139 at time  33.50314184197752
# Arrival  140 at time  35.29116524987202
# Arrival  141 at time  39.85821745612138
# Arrival  142 at time  40.995138069269075
# Arrival  143 at time  41.69271573031677
# Arrival  144 at time  41.7318557452925
# Arrival  145 at time  42.13273114946307
# Arrival  146 at time  44.14595062703466
# Arrival  147 at time  45.194517414211184
# Arrival  148 at time  46.576376759922994
# Arrival  149 at time  49.73788530451961
# Arrival  150 at time  50.56871224796266
# Arrival  151 at time  51.63341657240227
# Arrival  152 at time  52.56949297214298
# Arrival  153 at time  53.41639794591433
# Arrival  154 at time  56.808678508004746
# Arrival  155 at time  58.120763029108936
# Arrival  156 at time  58.126802710471914
# Arrival  157 at time  58.88682404933116
# Arrival  158 at time  59.90315307506594
# Arrival  159 at time  61.074955886127256
# Arrival  160 at time  64.78140739963177
# Arrival  161 at time  67.52598839672002
# Arrival  162 at time  68.05063391228059
# Arrival  163 at time  68.12550927467309
# Arrival  164 at time  69.00828207547106
# Arrival  165 at time  69.79462704956418
# Arrival  166 at time  70.98828489791615
# Arrival  167 at time  71.27934603076218
# Arrival  168 at time  72.1038652120703
# Arrival  169 at time  73.39518450616214
# Arrival  170 at time  75.78130630119732
# Arrival  171 at time  76.56964390604396
# Arrival  172 at time  77.41532570602135
# Arrival  173 at time  81.61901838595088
# Arrival  174 at time  84.29153794588908
# Arrival  175 at time  86.52990029518786
# Arrival  176 at time  87.19580898767879
# Arrival  177 at time  88.4353949652519
# Arrival  178 at time  95.97388850155188
# Arrival  179 at time  99.13837508501635
# Departure  113 at time  inf
# Arrival  179 at time  inf
# Departure  114 at time  inf
# Arrival  179 at time  inf
# Departure  115 at time  inf
# Arrival  179 at time  inf
# Departure  116 at time  inf
# Arrival  179 at time  inf
# Departure  117 at time  inf
# Arrival  179 at time  inf
# Departure  118 at time  inf
# Arrival  179 at time  inf
# Departure  119 at time  inf
# Arrival  179 at time  inf
# Departure  120 at time  inf
# Arrival  179 at time  inf
# Departure  121 at time  inf
# Arrival  179 at time  inf
# Departure  122 at time  inf
# Arrival  179 at time  inf
# Departure  123 at time  inf
# Arrival  179 at time  inf
# Departure  124 at time  inf
# Arrival  179 at time  inf
# Departure  125 at time  inf
# Arrival  179 at time  inf
# Departure  126 at time  inf
# Arrival  179 at time  inf
# Departure  127 at time  inf
# Arrival  179 at time  inf
# Departure  128 at time  inf
# Arrival  179 at time  inf
# Departure  129 at time  inf
# Arrival  179 at time  inf
# Departure  130 at time  inf
# Arrival  179 at time  inf
# Departure  131 at time  inf
# Arrival  179 at time  inf
# Departure  132 at time  inf
# Arrival  179 at time  inf
# Departure  133 at time  inf
# Arrival  179 at time  inf
# Departure  134 at time  inf
# Arrival  179 at time  inf
# Departure  135 at time  inf
# Arrival  179 at time  inf
# Departure  136 at time  inf
# Arrival  179 at time  inf
# Departure  137 at time  inf
# Arrival  179 at time  inf
# Departure  138 at time  inf
# Arrival  179 at time  inf
# Departure  139 at time  inf
# Arrival  179 at time  inf
# Departure  140 at time  inf
# Arrival  179 at time  inf
# Departure  141 at time  inf
# Arrival  179 at time  inf
# Departure  142 at time  inf
# Arrival  179 at time  inf
# Departure  143 at time  inf
# Arrival  179 at time  inf
# Departure  144 at time  inf
# Arrival  179 at time  inf
# Departure  145 at time  inf
# Arrival  179 at time  inf
# Departure  146 at time  inf
# Arrival  179 at time  inf
# Departure  147 at time  inf
# Arrival  179 at time  inf
# Departure  148 at time  inf
# Arrival  179 at time  inf
# Departure  149 at time  inf
# Arrival  179 at time  inf
# Departure  150 at time  inf
# Arrival  179 at time  inf
# Departure  151 at time  inf
# Arrival  179 at time  inf
# Departure  152 at time  inf
# Arrival  179 at time  inf
# Departure  153 at time  inf
# Arrival  179 at time  inf
# Departure  154 at time  inf
# Arrival  179 at time  inf
# Departure  155 at time  inf
# Arrival  179 at time  inf
# Departure  156 at time  inf
# Arrival  179 at time  inf
# Departure  157 at time  inf
# Arrival  179 at time  inf
# Departure  158 at time  inf
# Arrival  179 at time  inf
# Departure  159 at time  inf
# Arrival  179 at time  inf
# Departure  160 at time  inf
# Arrival  179 at time  inf
# Departure  161 at time  inf
# Arrival  179 at time  inf
# Departure  162 at time  inf
# Arrival  179 at time  inf
# Departure  163 at time  inf
# Arrival  179 at time  inf
# Departure  164 at time  inf
# Arrival  179 at time  inf
# Departure  165 at time  inf
# Arrival  179 at time  inf
# Departure  166 at time  inf
# Arrival  179 at time  inf
# Departure  167 at time  inf
# Arrival  179 at time  inf
# Departure  168 at time  inf
# Arrival  179 at time  inf
# Departure  169 at time  inf
# Arrival  179 at time  inf
# Departure  170 at time  inf
# Arrival  179 at time  inf
# Departure  171 at time  inf
# Arrival  179 at time  inf
# Departure  172 at time  inf
# Arrival  179 at time  inf
# Departure  173 at time  inf
# Arrival  179 at time  inf
# Departure  174 at time  inf
# Arrival  179 at time  inf
# Departure  175 at time  inf
# Arrival  179 at time  inf
# Departure  176 at time  inf
# Arrival  179 at time  inf
# Departure  177 at time  inf
# Arrival  179 at time  inf
# Departure  178 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# ...
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival  179 at time  inf
# Arrival
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 22
#      20 #append the new customer to the arrival list
#      21 arrivals.append(t)
# ---> 22 print("Arrival ", num_arrivals, "at time ", t)
#      25 # generate time of departure
#      26 if n == 1:
#
# File ~/.local/lib/python3.9/site-packages/ipykernel/iostream.py:550, in OutStream.write(self, string)
#     547     raise ValueError("I/O operation on closed file")
#     548 else:
# --> 550     is_child = not self._is_master_process()
#     551     # only touch the buffer in the IO thread to avoid races
#     552     with self._buffer_lock:
#
# File ~/.local/lib/python3.9/site-packages/ipykernel/iostream.py:438, in OutStream._is_master_process(self)
#     437 def _is_master_process(self):
# --> 438     return os.getpid() == self._master_pid
#
# KeyboardInterrupt:
